# %% [markdown]
# Write a Python program to print the even numbers from a given list.

# %%
list1 = [1,8,5,48,97,89,98,57,64,22,74] #definethe list
for num in list1:
   if num % 2 == 0:               #for even number condition
      print(num, end = " ")
# Out:
# 8 48 98 64 22 74
